# %% [markdown]
# # Impact

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import ocha_stratus as stratus

from src.constants import *

# %%
blob_name = f"{PROJECT_PREFIX}/raw/impact/cerf-storms-with-sids-2024-02-27.csv"

# %%
df_cerf = stratus.load_csv_from_blob(blob_name)

# %%
df_cerf_cub =
# Out:
#                 Country Allocation date  Amount in US$          Window  \
# 0   Antigua and Barbuda      2017-10-04        2154461  Rapid Response
# 1               Bahamas      2019-09-26        1002151  Rapid Response
# 2            Bangladesh      2023-06-14        3000000  Rapid Response
# 3            Bangladesh      2020-06-17        5012069  Rapid Response
# 4            Bangladesh      2017-06-15        1730610  Rapid Response
# ..                  ...             ...            ...             ...
# 77              Vanuatu      2020-05-05        2605385  Rapid Response
# 78              Vanuatu      2015-03-27        5038408  Rapid Response
# 79             Viet Nam      2017-11-28        4213259  Rapid Response
# 80             Zimbabwe      2019-04-08        4055106  Rapid Response
# 81             Zimbabwe      2011-03-31         977054  Rapid Response
#
#    Emergency            Status iso2  asap0_id  allocation_year            sid
# 0      Storm  Report Available   AG        64             2017  2017242N16333
# 1      Storm  Report Available   BS        76             2019  2019236N10314
# 2      Storm         Completed   BD        20             2023            NaN
# 3      Storm  Report Available   BD        20             2020  2020136N10088
# 4      Storm  Report Available   BD        20             2017  2017147N14087
# ..       ...               ...  ...       ...              ...            ...
# 77     Storm  Report Available   VU       211             2020  2020092S09155
# 78     Storm  Report Available   VU       211             2015  2015066S08170
# 79     Storm  Report Available   VN       134             2017  2017304N11127
# 80     Storm  Report Available   ZW       218             2019  2019063S18038
# 81     Storm  Report Available   ZW       218             2011            NaN
#
# [82 rows x 10 columns]
