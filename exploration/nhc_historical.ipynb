# %% [markdown]
# # Historical NHC
#
# Download and process historical NHC forecasts

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
from src.datasources import nhc

# %%
nhc.download_historical_forecasts(start_year=2023, end_year=2024)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (24,27,28,29,30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)
# /Users/tdowning/OCHA/repos/ds-aa-cub-hurricanes/src/datasources/nhc.py:65: DtypeWarning: Columns (39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None, names=nhc_cols)

# %%
nhc.process_historical_forecasts()
# Out:
#   0%|          | 0/454 [00:00<?, ?it/s]
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (23,25,26,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (23,25,26,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (23,25,26,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (23,26,30,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (22,24,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (27,29,30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (36,40,42,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (36,40,42,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (36,40,42,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (35,39,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (35,36,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (24,27,28,29,30,35,39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
# /Users/tdowning/.pyenv/versions/ds-aa-cub-hurricanes/lib/python3.11/site-packages/ocha_stratus/azure_blob.py:186: DtypeWarning: Columns (39,41,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(blob_data), **kwargs)
